# %% [markdown]
# **Esta es una práctica de Jupyter Notebook**

# %% [markdown]
# # Titulo 1
# ## Titulo 2
# ### Titulo 3

# %% [markdown]
# - Elemento de lista 1
# - Elemento de lista 2
# * Elemento de lista 3
# * Elemento de lista 4
# + Elemento de lista 5
# + Elemento de lista 6

# %% [markdown]
# - Item 1
#   + Sub item 1
#   + Sub item 2
# - Item 2
#   1. Sub item 1
#   2. Sub item 2
# - Item 3

# %% [markdown]
# ***Qué es MarkDown***

# %% [markdown]
# **MarkDown** es un lenguaje ligero de marcado de texto que *permite escribir* sin despegar los dedos del teclado.

# %% [markdown]
# [Markdown](http://es.wikipedia.org/wiki/Markdown "Wikipedia")

# %% [markdown]
# ![dikw%20pyramid.png](attachment:dikw%20pyramid.png)
